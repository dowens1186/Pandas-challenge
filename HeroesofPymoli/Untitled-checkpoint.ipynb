# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
unique = purchase_data_df["SN"].unique()

# %%
unique
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Chanosian48', 'Inguron55', 'Haisrisuir60', 'Saelaephos52',
#        'Assjaskan73', 'Saesrideu94', 'Lisassa64', 'Lisirra25',
#        'Zontibe81', 'Reunasu60', 'Chamalo71', 'Iathenudil29',
#        'Phiarithdeu40', 'Siarithria38', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Reulae52',
#        'Sondilsaya62', 'Aerithriaphos45', 'Assosia88', 'Aidaillodeu39',
#        'Aelly27', 'Tyeosri53', 'Haerith37', 'Yasrisu92', 'Chanuchi25',
#        'Asur96', 'Iaralrgue74', 'Chanosia34', 'Aelin32', 'Ilosianya35',
#        'Zhisrisu83', 'Phaelap26', 'Raesty92', 'Palyon91', 'Tyisur83',
#        'Yaliru88', 'Yadanu52', 'Jiskimya77', 'Yadaphos40', 'Alo38',
# ...

# %%
count = purchase_data_df["SN"].value_counts()
count
# Out:
# Lisosia93      5
# Iral74         4
# Idastidru52    4
# Tyidaim51      3
# Zontibe81      3
#               ..
# Indonmol95     1
# Philodil43     1
# Eodaisu60      1
# Tyidainu31     1
# Firan91        1
# Name: SN, Length: 576, dtype: int64

# %%
data = [[0 , 576]]
df = pd.DataFrame(data, columns = ["", 'Total Players'])
df
# Out:
#       Total Players
# 0  0            576

# %%
purchase_data_df.describe()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   91.755128    3.050987
# std     225.310896    6.659444   52.697702    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   47.750000    1.980000
# 50%     389.500000   22.000000   92.000000    3.150000
# 75%     584.250000   25.000000  138.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
count = purchase_data_df["Item Name"].value_counts()
count
# Out:
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Extraction, Quickblade Of Trembling Hands        9
# Persuasion                                       9
# Fiery Glass Crusader                             9
#                                                 ..
# Celeste                                          1
# Exiled Mithril Longsword                         1
# Riddle, Tribute of Ended Dreams                  1
# Endbringer                                       1
# Undead Crusader                                  1
# Name: Item Name, Length: 179, dtype: int64

# %%
count = purchase_data_df["Price"].value_counts()
count
# Out:
# 4.40    21
# 4.23    20
# 4.35    14
# 2.18    14
# 1.02    14
#         ..
# 2.17     1
# 4.17     1
# 1.99     1
# 4.50     1
# 3.30     1
# Name: Price, Length: 145, dtype: int64

# %%
total = purchase_data_df['Price'].sum()
total
# Out:
# 2379.77

# %%
df.dtypes
# Out:
# Number of Unique Items      int64
# Average Price             float64
# Number of Purchases         int64
# Total Revenue             float64
# dtype: object

# %%
count = purchase_data_df["Gender"].value_counts()
count
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
df = {
     'Gender': ['Male', 'Female', 'Other/Non-Disclosed'],
     'Total Count': [652, 113, 15]}
df = pd.DataFrame(df1,
                  columns = ['Gender',
                            'Total Count'])
df
# Out:
#                 Gender  Total Count
# 0                 Male          652
# 1               Female          113
# 2  Other/Non-Disclosed           15

# %%
df['percent'] = df['Total Count']/df['Total Count'].sum() * 100
df['percent']
# Out:
# 0    83.589744
# 1    14.487179
# 2     1.923077
# Name: percent, dtype: float64

# %%
gender_percent = purchase_data_df['Gender'].value_counts('Male')*100
gender_count = (gender_percent/100)*780
df = pd.DataFrame({"Total Count": gender_count, "Percentage of Players": gender_percent})
df.style.format({"Percentage of Players":"%{:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6row0_col0" class="data row0 col0" >652.000000</td>
#                         <td id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6row0_col1" class="data row0 col1" >%83.59</td>
#             </tr>
#             <tr>
#                         <th id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_3c17a1d2_e3f7_11eb_88bf_e0d55e6e9dd6row1_col0" class="data row1 col0" >113.000000</td>
# ...

# %%
gender = purchase_data_df.groupby("Gender")

# %%
gender_price_avg = gender["Price"].mean()

# %%
gender = purchase_data_df.groupby("Gender")
gender_price_avg = gender("Price").mean()
gender_purchase_value = gender("Price").sum()
gender_avg = gender_purchase_value/gender_count

df = pd.DataFrame({"Purchase Count": gender_count, "Average Purchase Price": gender_price_avg, "Total Purchase Value": gender_purchase_value, "Avg Total Purchase per Person": gender_avg})
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-519525bf5fa0> in <module>
#       1 gender = purchase_data_df.groupby("Gender")
# ----> 2 gender_price_avg = gender("Price").mean()
#       3 gender_purchase_value = gender("Price").sum()
#       4 gender_avg = gender_purchase_value/gender_count
#       5
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
gender = purchase_data_df.groupby("Gender")
gender_price_avg = gender["Price"].mean()
gender_purchase_val = gender["Price"].sum()
gender_total_avg = gender_purchase_val/count_gender

df = pd.DataFrame({"Purchase Count": count_gender, "Average Purchase Price": gender_price_avg, "Total Purchase Value": gender_purchase_val,"Avg Total Per Person":gender_total_avg})
df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Female                          113.0                3.203009
# Male                            652.0                3.017853
# Other / Non-Disclosed            15.0                3.346000
#
#                        Total Purchase Value  Avg Total Per Person
# Female                               361.94              3.203009
# Male                                1967.64              3.017853
# Other / Non-Disclosed                 50.19              3.346000

# %%
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
unique = purchase_data_df["Age"].unique()
unique
# Out:
# array([20, 40, 24, 23, 22, 36, 35, 21, 30, 38, 29, 11,  7, 19, 37, 10,  8,
#        18, 27, 33, 32, 25, 12, 34, 17, 15, 13, 26, 16, 28, 31, 39, 44, 41,
#         9, 14, 42, 43, 45], dtype=int64)

# %%
bins_age = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 100]
grouped_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_data_df["Age Group"] = pd.cut(purchase_data_df["Age"],bins_age, labels=grouped_name)
purchase_data_df
age_group = purchase_data_df.groupby("Age Group")
total_age = age_group["SN"].nunique()
percentage_age = (total_age/576) * 100
age_demographics = pd.DataFrame({"Total Count":total_age,"Percentage of Players": percentage_age})
age_demographics
# Out:
#            Total Count  Percentage of Players
# Age Group
# <10                 17               2.951389
# 10-14               22               3.819444
# 15-19              107              18.576389
# 20-24              258              44.791667
# 25-29               77              13.368056
# 30-34               52               9.027778
# 35-39               31               5.381944
# 40+                 12               2.083333

# %%
bins_age = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 100]
grouped_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_data_df["Age Group"] = pd.cut(purchase_data_df["Age"],bins_age, labels=grouped_name)
purchase_data_df
age_group = purchase_data_df.groupby("Age Group")
total_age = age_group["SN"].nunique()
percentage_age = (total_age/576) * 100
age_demographics = pd.DataFrame({"Total Count":total_age,"Percentage of Players": percentage_age})
age_demographics.index.name = None
age_demographics.style.format({"Percentage of Players":"%{:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6row0_col1" class="data row0 col1" >%2.95</td>
#             </tr>
#             <tr>
#                         <th id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_1d4322cc_e3ff_11eb_9d66_e0d55e6e9dd6row1_col0" class="data row1 col0" >22</td>
# ...

# %%
bins_age = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 100]
grouped_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_age_count = age_group["Purchase ID"].count()
Average_purchase_price_age = age_group["Price"].mean()
total_purchase_value = age_group["Price"].sum()
Average_purchase_person_age = total_purchase_value/total_age
age_demographics = pd.DataFrame({"Purchase Count": purchase_age_count,
                                 "Average Purchase Price": Average_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": Average_purchase_person_age})
age_demographics
# Out:
#        Purchase Count  Average Purchase Price  Total Purchase Value  \
# <10                23                3.353478                 77.13
# 10-14              28                2.956429                 82.78
# 15-19             136                3.035956                412.89
# 20-24             365                3.052219               1114.06
# 25-29             101                2.900990                293.00
# 30-34              73                2.931507                214.00
# 35-39              41                3.601707                147.67
# 40+                13                2.941538                 38.24
#
#        Average Purchase Total per Person
# <10                             4.537059
# 10-14                           3.762727
# 15-19                           3.858785
# 20-24                           4.318062
# 25-29                           3.805195
# 30-34                           4.115385
# 35-39                           4.763548
# ...

# %%
bins_age = [0, 9.99, 14.99, 19.99, 24.99, 29.99, 34.99, 39.99, 100]
grouped_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_age_count = age_group["Purchase ID"].count()
Average_purchase_price_age = age_group["Price"].mean()
total_purchase_value = age_group["Price"].sum()
Average_purchase_person_age = total_purchase_value/total_age
age_demographics = pd.DataFrame({"Purchase Count": purchase_age_count,
                                 "Average Purchase Price": Average_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": Average_purchase_person_age})
age_demographics.style.format({"Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}",
                               "Average Purchase Total per Person":"${:2,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4f4fa412_e411_11eb_b950_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Average Purchase Total per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f4fa412_e411_11eb_b950_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_4f4fa412_e411_11eb_b950_e0d55e6e9dd6row0_col0" class="data row0 col0" >23</td>
# ...

# %%
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
top_spenders = purchase_data_df.groupby("SN")
purchase_spender = top_spenders["Purchase ID"].count()
average_price_per_spender = top_spenders["Price"].mean()
purchase_total = top_spenders["Price"].sum()
top_spenders = pd.DataFrame({"Purchase Count": purchase_spender
                             "Average Purchase Price": average_price_per_spender
                             "Total Purchase Value": purchase_total})
format_spenders = top_spenders.sort.value(["Total Purchase Value"], descending=True).head()
format_spenders.style.format({"Average Purchase Total":"${:,.2f}","Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
#   File "<ipython-input-122-fd0536398686>", line 6
#     "Average Purchase Price": average_price_per_spender
#                            ^
# SyntaxError: invalid syntax

# %%
top_spenders = purchase_data_df.groupby("SN")
purchasing_spender = top_spenders["Purchase ID"].count()
Average_purchasing_price_per_spender = top_spenders["Price"].mean()
purchase_total_spender = top_spenders["Price"].sum()
top_spenders = pd.DataFrame({"Purchase Count": purchasing_spender,
                             "Average Purchase Price": Average_purchasing_price_per_spender,
                             "Total Purchase Value":purchase_total_spender})
top_spenders
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                1                2.280000                  2.28
# Adastirin33                 1                4.480000                  4.48
# Aeda94                      1                4.910000                  4.91
# Aela59                      1                4.320000                  4.32
# Aelaria33                   1                1.790000                  1.79
# ...                       ...                     ...                   ...
# Yathecal82                  3                2.073333                  6.22
# Yathedeu43                  2                3.010000                  6.02
# Yoishirrala98               1                4.580000                  4.58
# Zhisrisu83                  2                3.945000                  7.89
# Zontibe81                   3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
top_spenders = purchase_data_df.groupby("SN")
purchasing_spender = top_spenders["Purchase ID"].count()
Average_purchasing_price_per_spender = top_spenders["Price"].mean()
purchase_total_spender = top_spenders["Price"].sum()
top_spenders = pd.DataFrame({"Purchase Count": purchasing_spender,
                             "Average Purchase Price": Average_purchasing_price_per_spender,
                             "Total Purchase Value":purchase_total_spender})
format_spenders_frame = top_spenders.sort_values(["Total Purchase Value"], ascending=False).head()
format_spenders_frame.style.format({"Average Purchase Total":"${:,.2f}","Average Purchase Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_e03baf34_e336_11eb_b338_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e03baf34_e336_11eb_b338_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_e03baf34_e336_11eb_b338_e0d55e6e9dd6row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_e03baf34_e336_11eb_b338_e0d55e6e9dd6row0_col1" class="data row0 col1" >$3.79</td>
# ...

# %%
item_name = purchase_data_df[["Item ID", "Item Name", "Price"]]
item_group = item_name.groupby(["Item ID","Item Name"])
purchasing_item = item_group["Price"].count()
purchasing_value = (item_group["Price"].sum()) 
price = purchasing_value/purchasing_item
popular_items = pd.DataFrame({"Purchase Count": purchasing_item, 
                                   "Item Price": price,
                                   "Total Purchase Value":purchasing_value})
popular_items
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# ...                                                              ...
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 179     Wolf, Promise of the Moonwalker                            6
# 181     Reaper's Toll                                              5
# 182     Toothpick                                                  3
# 183     Dragon's Greatsword                                        3
#
#                                                       Item Price  \
# Item ID Item Name
# ...

# %%
item_name = purchase_data_df[["Item ID", "Item Name", "Price"]]
item_group = item_name.groupby(["Item ID","Item Name"])
purchasing_item = item_group["Price"].count()
purchasing_value = (item_group["Price"].sum()) 
price = purchasing_value/purchasing_item
popular_items = pd.DataFrame({"Purchase Count": purchasing_item, 
                                   "Item Price": price,
                                   "Total Purchase Value":purchasing_value})
popular_format = popular_items.sort_values(["Purchase Count"], ascending=False).head()
popular_format
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
item_name = purchase_data_df[["Item ID", "Item Name", "Price"]]
item_group = item_name.groupby(["Item ID","Item Name"])
purchasing_item = item_group["Price"].count()
purchasing_value = (item_group["Price"].sum()) 
price = purchasing_value/purchasing_item
popular_items = pd.DataFrame({"Purchase Count": purchasing_item, 
                                   "Item Price": price,
                                   "Total Purchase Value":purchasing_value})
popular_format = popular_items.sort_values(["Purchase Count"], ascending=False).head()
popular_format.style.format({"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3aaea8c2_e339_11eb_8f77_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3aaea8c2_e339_11eb_8f77_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_3aaea8c2_e339_11eb_8f77_e0d55e6e9dd6level1_row0" class="row_heading level1 row0" >Final Critic</th>
# ...

# %%
purchase_value_format = popular_items.sort_values(["Total Purchase Value"],ascending=False).head()
purchase_value_format
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
purchase_value_format.style.format({"Item Price":"${:,.2f}","Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_375dce0a_e33b_11eb_8849_e0d55e6e9dd6" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_375dce0a_e33b_11eb_8849_e0d55e6e9dd6level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_375dce0a_e33b_11eb_8849_e0d55e6e9dd6level1_row0" class="row_heading level1 row0" >Final Critic</th>
# ...

# %%
# The age groups 15-19, 20-24 and 25-29 make up an overwhelming majority of all users at almost 77% of all users.
# Female users spending more an average than male users, at an average of $3.20 per item for females, versus $3.01 for males.
# Surprisingly, the second largest spending of age groups is at the age groups younger than 10, at an average of $4.54 purchased per person. Parent's credit cards maybe?
